# %%
from sklearn.datasets import mnis
# Out:
# Dữ liệu đầu vào:
# Điểm 1: [1, 2]
# Điểm 2: [1.5, 1.8]
# Điểm 3: [5, 8]
# Điểm 4: [8, 8]
# Điểm 5: [1, 0.6]
# Điểm 6: [9, 11]
# Điểm 7: [8, 2]
# Điểm 8: [10, 2]
# Điểm 9: [9, 3]
# Điểm 10: [2, 1]
# Điểm 11: [6, 9]
# Điểm 12: [7, 10]
# Điểm 13: [2, 2]
# Điểm 14: [1.5, 2.5]
# Điểm 15: [8.5, 8]
# Hội tụ sau 2 vòng lặp
#
# ...
# KẾT QUẢ PHÂN CỤM
# ...
#
# Centroids cuối cùng:
# Cụm 1: [1.5, 1.65]
# Cụm 2: [7.25, 9.0]
# Cụm 3: [9.0, 2.33]
#
# Các cụm:
#
# Cụm 1 (6 điểm):
#   [1, 2]
#   [1.5, 1.8]
#   [1, 0.6]
#   [2, 1]
#   [2, 2]
#   [1.5, 2.5]
#
# Cụm 2 (6 điểm):
#   [5, 8]
#   [8, 8]
#   [9, 11]
#   [6, 9]
#   [7, 10]
#   [8.5, 8]
#
# Cụm 3 (3 điểm):
#   [8, 2]
#   [10, 2]
#   [9, 3]
#
# ...
# DỰ ĐOÁN ĐIỂM MỚI
# ...
# Điểm [2, 2] thuộc cụm 1
# Điểm [8, 9] thuộc cụm 2

# %%
from sk
